# %%
#put the age_response data into individual lists

age_data = age_response['results']
age_years = age_data[0]['data_year']

years = []

for age_years in age_data:
    years.append(age_years['data_year'])
    
years

age_data = age_response['results']
age_range1 = age_data[0]['range_0_9']

range1 = []

for age_range1 in age_data:
    range1.append(age_range1['range_0_9'])

range1
    

    
    
    states = (state.iloc[:, 1]).astype(str)#states = (state.iloc[:, 1]).astype(str)
    
    
    
    "pagination" : {
    "count" : 58,
    "page" : 0,
    "pages" : 3,
    "per_page" : 20
  }
}

state_data_1 = state_results_1['results']
state_data_2 = state_results_2['results']
state_data_3 = state_results_3['results']

state_data_1.append(state_data_2)
state_data_1.append(state_data_3)

#state_data_1


#States .csv file
#path = "Resources/states.csv"
#states_df = pd.read_csv(path, encoding='ISO-8859-1', header=None)
#states_df.head()



age_results = []
    
for i in age_queries:
    age_response = requests.get(i).json()
    age_results.append([{i : age_response}])
    
age_results



#Using state_data to dynamically build our list of queries, one for each state in state_data
#Will return a list of query urls:  age_queries
#Also creates a new list of just the state abbreviations:  state_abbr

states = (state_data.iloc[:,1]).astype(str)

age_queries = []
state_abbr = []

for i in states:
    age_query_url = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/victim/states/" + i + "/age?api_key=" + ses_dg_key
    age_queries.append(age_query_url)
    state_abbr.append(states)
    #age_response_state = requests.get(age_query_url).json
    
#age_queries
#state_abbr
