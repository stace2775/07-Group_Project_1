# %%
#

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import csv
import time

from pprint import pprint

# Import DATA.GOV API key
from api_keys import ld_dg_key

# Output File (CSV)
output_data_file = "output_data/fbi_crime_data.csv"
homicide_output_data_file = "../homicide_mortality.csv"

# %%
homicide_output_data_file = "../homicide_mortality.csv"

# %%
# State Abbreviations

# %%
#Pull all pages for the data for each state 
state_qry ="https://api.usa.gov/crime/fbi/sapi/api/states?api_key=" + ld_dg_key
state_results_1 = requests.get(state_qry, params={'page':0}).json()
state_results_2 = requests.get(state_qry, params={'page':1}).json()
state_results_3 = requests.get(state_qry, params={'page':2}).json()

 #Make DFs for each page of data
sr1_df = pd.DataFrame(state_results_1['results'])
sr2_df = pd.DataFrame(state_results_2['results'])
sr3_df = pd.DataFrame(state_results_3['results'])

# Setting up a sleep command.
time.sleep(5)

#Combine DFs of each page into one DF for all data
state_data = pd.concat([sr1_df, sr2_df, sr3_df])

state_data.head()
# Out:
#    region_code state_abbr  state_fips_code  state_id      state_name
# 0            4         AK              2.0         1          Alaska
# 1            3         AL              1.0         2         Alabama
# 2            3         AR              5.0         3        Arkansas
# 3           99         AS             60.0         4  American Samoa
# 4            4         AZ              4.0         5         Arizona

# %%
test_query = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/violent-crime/offender/national/age?api_key=" + ld_dg_key

test_response = requests.get(test_query).json()
test_response
# Out:
# {'results': [{'unknown': 461,
#    'range_0_9': 3,
#    'range_10_19': 735,
#    'range_20_29': 1469,
#    'range_30_39': 585,
#    'range_40_49': 373,
#    'range_50_59': 192,
#    'range_60_69': 53,
#    'range_70_79': 28,
#    'range_80_89': 13,
#    'range_90_99': 9,
#    'data_year': 2008},
#   {'unknown': 2491,
#    'range_0_9': 29,
#    'range_10_19': 4406,
#    'range_20_29': 5707,
#    'range_30_39': 2256,
#    'range_40_49': 504,
#    'range_50_59': 121,
#    'range_60_69': 15,
#    'range_70_79': 5,
#    'range_80_89': 1,
#    'range_90_99': 52,
#    'data_year': 1996},
#   {'unknown': 11522,
#    'range_0_9': 79,
#    'range_10_19': 10880,
#    'range_20_29': 14952,
#    'range_30_39': 5439,
#    'range_40_49': 1854,
#    'range_50_59': 554,
#    'range_60_69': 69,
#    'range_70_79': 10,
#    'range_80_89': 2,
#    'range_90_99': 84,
#    'data_year': 2000},
#   {'unknown': 4279,
#    'range_0_9': 161,
#    'range_10_19': 7985,
#    'range_20_29': 9451,
#    'range_30_39': 6613,
#    'range_40_49': 3878,
#    'range_50_59': 2320,
#    'range_60_69': 775,
#    'range_70_79': 184,
#    'range_80_89': 41,
#    'range_90_99': 70,
#    'data_year': 2016},
#   {'unknown': 449,
#    'range_0_9': 54,
#    'range_10_19': 1158,
#    'range_20_29': 1656,
#    'range_30_39': 1153,
#    'range_40_49': 400,
#    'range_50_59': 138,
#    'range_60_69': 38,
#    'range_70_79': 10,
#    'range_80_89': 0,
#    'range_90_99': 11,
#    'data_year': 1994},
#   {'unknown': 27282,
#    'range_0_9': 213,
#    'range_10_19': 32327,
#    'range_20_29': 39118,
#    'range_30_39': 12173,
#    'range_40_49': 6053,
#    'range_50_59': 1437,
#    'range_60_69': 139,
#    'range_70_79': 17,
#    'range_80_89': 12,
#    'range_90_99': 228,
#    'data_year': 2007},
#   {'unknown': 57,
#    'range_0_9': 51,
#    'range_10_19': 383,
#    'range_20_29': 233,
#    'range_30_39': 225,
#    'range_40_49': 99,
#    'range_50_59': 37,
#    'range_60_69': 16,
#    'range_70_79': 7,
#    'range_80_89': 4,
#    'range_90_99': 0,
#    'data_year': 1995},
#   {'unknown': 563,
#    'range_0_9': 4,
#    'range_10_19': 683,
#    'range_20_29': 1535,
#    'range_30_39': 703,
#    'range_40_49': 416,
#    'range_50_59': 236,
#    'range_60_69': 76,
#    'range_70_79': 33,
#    'range_80_89': 10,
#    'range_90_99': 3,
#    'data_year': 2011},
#   {'unknown': 8230,
#    'range_0_9': 507,
#    'range_10_19': 21343,
#    'range_20_29': 27759,
#    'range_30_39': 20494,
#    'range_40_49': 11062,
#    'range_50_59': 3443,
#    'range_60_69': 973,
#    'range_70_79': 315,
#    'range_80_89': 83,
#    'range_90_99': 158,
#    'data_year': 1999},
#   {'unknown': 259,
#    'range_0_9': 114,
#    'range_10_19': 791,
#    'range_20_29': 599,
#    'range_30_39': 471,
#    'range_40_49': 301,
#    'range_50_59': 145,
#    'range_60_69': 69,
#    'range_70_79': 24,
#    'range_80_89': 4,
#    'range_90_99': 3,
#    'data_year': 2004},
#   {'unknown': 2301,
#    'range_0_9': 121,
#    'range_10_19': 5179,
#    'range_20_29': 6009,
#    'range_30_39': 3691,
#    'range_40_49': 1898,
#    'range_50_59': 634,
#    'range_60_69': 223,
#    'range_70_79': 54,
#    'range_80_89': 9,
#    'range_90_99': 32,
#    'data_year': 2002},
#   {'unknown': 76,
#    'range_0_9': 12,
#    'range_10_19': 106,
#    'range_20_29': 150,
#    'range_30_39': 125,
#    'range_40_49': 58,
#    'range_50_59': 27,
#    'range_60_69': 7,
#    'range_70_79': 3,
#    'range_80_89': 1,
#    'range_90_99': 0,
#    'data_year': 1993},
#   {'unknown': 483,
#    'range_0_9': 218,
#    'range_10_19': 2193,
#    'range_20_29': 1443,
#    'range_30_39': 1078,
#    'range_40_49': 763,
#    'range_50_59': 409,
#    'range_60_69': 114,
#    'range_70_79': 60,
#    'range_80_89': 16,
#    'range_90_99': 3,
#    'data_year': 2010},
#   {'unknown': 245,
#    'range_0_9': 0,
#    'range_10_19': 420,
#    'range_20_29': 968,
#    'range_30_39': 408,
#    'range_40_49': 266,
#    'range_50_59': 90,
#    'range_60_69': 33,
#    'range_70_79': 24,
#    'range_80_89': 3,
#    'range_90_99': 6,
#    'data_year': 2003},
#   {'unknown': 606,
#    'range_0_9': 6,
#    'range_10_19': 821,
#    'range_20_29': 1500,
#    'range_30_39': 644,
#    'range_40_49': 406,
#    'range_50_59': 163,
#    'range_60_69': 50,
#    'range_70_79': 15,
#    'range_80_89': 7,
#    'range_90_99': 4,
#    'data_year': 2006},
#   {'unknown': 26193,
#    'range_0_9': 142,
#    'range_10_19': 25284,
#    'range_20_29': 38780,
#    'range_30_39': 11711,
#    'range_40_49': 5124,
#    'range_50_59': 1834,
#    'range_60_69': 170,
#    'range_70_79': 30,
#    'range_80_89': 3,
#    'range_90_99': 169,
#    'data_year': 2012},
#   {'unknown': 484,
#    'range_0_9': 247,
#    'range_10_19': 2538,
#    'range_20_29': 1588,
#    'range_30_39': 1177,
#    'range_40_49': 850,
#    'range_50_59': 497,
#    'range_60_69': 165,
#    'range_70_79': 55,
#    'range_80_89': 15,
#    'range_90_99': 15,
#    'data_year': 2013},
#   {'unknown': 516,
#    'range_0_9': 3,
#    'range_10_19': 763,
#    'range_20_29': 1522,
#    'range_30_39': 651,
#    'range_40_49': 400,
#    'range_50_59': 196,
#    'range_60_69': 74,
#    'range_70_79': 28,
#    'range_80_89': 10,
#    'range_90_99': 8,
#    'data_year': 2009},
#   {'unknown': 25545,
#    'range_0_9': 97,
#    'range_10_19': 22241,
#    'range_20_29': 31857,
#    'range_30_39': 13482,
#    'range_40_49': 4791,
#    'range_50_59': 2472,
#    'range_60_69': 308,
#    'range_70_79': 34,
#    'range_80_89': 10,
#    'range_90_99': 184,
#    'data_year': 2017},
#   {'unknown': 3425,
#    'range_0_9': 142,
#    'range_10_19': 6789,
#    'range_20_29': 8314,
#    'range_30_39': 4800,
#    'range_40_49': 3178,
#    'range_50_59': 1339,
#    'range_60_69': 352,
#    'range_70_79': 78,
#    'range_80_89': 18,
#    'range_90_99': 48,
#    'data_year': 2008},
#   {'unknown': 22692,
#    'range_0_9': 163,
#    'range_10_19': 24489,
#    'range_20_29': 32894,
#    'range_30_39': 11407,
#    'range_40_49': 5030,
#    'range_50_59': 1137,
#    'range_60_69': 145,
#    'range_70_79': 26,
#    'range_80_89': 10,
#    'range_90_99': 107,
#    'data_year': 2005},
#   {'unknown': 3503,
#    'range_0_9': 20,
#    'range_10_19': 5560,
#    'range_20_29': 6773,
#    'range_30_39': 2702,
#    'range_40_49': 701,
#    'range_50_59': 179,
#    'range_60_69': 16,
#    'range_70_79': 3,
#    'range_80_89': 2,
#    'range_90_99': 126,
#    'data_year': 1997},
#   {'unknown': 655,
#    'range_0_9': 298,
#    'range_10_19': 2648,
#    'range_20_29': 1840,
#    'range_30_39': 1396,
#    'range_40_49': 888,
#    'range_50_59': 624,
#    'range_60_69': 184,
#    'range_70_79': 61,
#    'range_80_89': 13,
#    'range_90_99': 11,
#    'data_year': 2015},
#   {'unknown': 790,
#    'range_0_9': 2,
#    'range_10_19': 772,
#    'range_20_29': 1952,
#    'range_30_39': 927,
#    'range_40_49': 476,
#    'range_50_59': 316,
#    'range_60_69': 115,
#    'range_70_79': 39,
#    'range_80_89': 16,
#    'range_90_99': 3,
#    'data_year': 2016},
#   {'unknown': 86,
#    'range_0_9': 0,
#    'range_10_19': 214,
#    'range_20_29': 325,
#    'range_30_39': 136,
#    'range_40_49': 74,
#    'range_50_59': 21,
#    'range_60_69': 8,
#    'range_70_79': 6,
#    'range_80_89': 0,
#    'range_90_99': 0,
#    'data_year': 1994},
#   {'unknown': 5685,
#    'range_0_9': 313,
#    'range_10_19': 13989,
#    'range_20_29': 17437,
#    'range_30_39': 11054,
#    'range_40_49': 4415,
#    'range_50_59': 1437,
#    'range_60_69': 471,
#    'range_70_79': 142,
#    'range_80_89': 34,
#    'range_90_99': 35,
#    'data_year': 1993},
#   {'unknown': 3676,
#    'range_0_9': 112,
#    'range_10_19': 6775,
#    'range_20_29': 8429,
#    'range_30_39': 5075,
#    'range_40_49': 3411,
#    'range_50_59': 1637,
#    'range_60_69': 433,
#    'range_70_79': 121,
#    'range_80_89': 30,
#    'range_90_99': 34,
#    'data_year': 2011},
#   {'unknown': 601,
#    'range_0_9': 249,
#    'range_10_19': 2583,
#    'range_20_29': 1656,
#    'range_30_39': 1199,
#    'range_40_49': 846,
#    'range_50_59': 536,
#    'range_60_69': 174,
#    'range_70_79': 55,
#    'range_80_89': 11,
#    'range_90_99': 6,
#    'data_year': 2014},
#   {'unknown': 5132,
#    'range_0_9': 64,
#    'range_10_19': 6770,
#    'range_20_29': 8252,
#    'range_30_39': 3701,
#    'range_40_49': 1003,
#    'range_50_59': 213,
#    'range_60_69': 25,
#    'range_70_79': 6,
#    'range_80_89': 2,
#    'range_90_99': 161,
#    'data_year': 1998},
#   {'unknown': 69,
#    'range_0_9': 16,
#    'range_10_19': 244,
#    'range_20_29': 188,
#    'range_30_39': 168,
#    'range_40_49': 66,
#    'range_50_59': 27,
#    'range_60_69': 10,
#    'range_70_79': 1,
#    'range_80_89': 1,
#    'range_90_99': 1,
#    'data_year': 1992},
#   {'unknown': 267,
#    'range_0_9': 1,
#    'range_10_19': 367,
#    'range_20_29': 892,
#    'range_30_39': 428,
#    'range_40_49': 232,
#    'range_50_59': 103,
#    'range_60_69': 29,
#    'range_70_79': 19,
#    'range_80_89': 9,
#    'range_90_99': 3,
#    'data_year': 2002},
#   {'unknown': 106,
#    'range_0_9': 26,
#    'range_10_19': 175,
#    'range_20_29': 126,
#    'range_30_39': 133,
#    'range_40_49': 54,
#    'range_50_59': 14,
#    'range_60_69': 10,
#    'range_70_79': 0,
#    'range_80_89': 0,
#    'range_90_99': 0,
#    'data_year': 1991},
#   {'unknown': 2383,
#    'range_0_9': 118,
#    'range_10_19': 5087,
#    'range_20_29': 5918,
#    'range_30_39': 3566,
#    'range_40_49': 2209,
#    'range_50_59': 757,
#    'range_60_69': 228,
#    'range_70_79': 55,
#    'range_80_89': 15,
#    'range_90_99': 22,
#    'data_year': 2003},
#   {'unknown': 328,
#    'range_0_9': 240,
#    'range_10_19': 1706,
#    'range_20_29': 735,
#    'range_30_39': 682,
#    'range_40_49': 391,
#    'range_50_59': 149,
#    'range_60_69': 60,
#    'range_70_79': 20,
#    'range_80_89': 2,
#    'range_90_99': 9,
#    'data_year': 2001},
#   {'unknown': 3535,
#    'range_0_9': 129,
#    'range_10_19': 6704,
#    'range_20_29': 8492,
#    'range_30_39': 4787,
#    'range_40_49': 3070,
#    'range_50_59': 1161,
#    'range_60_69': 344,
#    'range_70_79': 69,
#    'range_80_89': 18,
#    'range_90_99': 40,
#    'data_year': 2006},
#   {'unknown': 14984,
#    'range_0_9': 568,
#    'range_10_19': 34177,
#    'range_20_29': 48528,
#    'range_30_39': 28920,
#    'range_40_49': 20317,
#    'range_50_59': 6723,
#    'range_60_69': 1717,
#    'range_70_79': 524,
#    'range_80_89': 129,
#    'range_90_99': 157,
#    'data_year': 2004},
#   {'unknown': 158,
#    'range_0_9': 53,
#    'range_10_19': 440,
#    'range_20_29': 325,
#    'range_30_39': 327,
#    'range_40_49': 173,
#    'range_50_59': 112,
#    'range_60_69': 35,
#    'range_70_79': 8,
#    'range_80_89': 2,
#    'range_90_99': 5,
#    'data_year': 1999},
#   {'unknown': 3626,
#    'range_0_9': 135,
#    'range_10_19': 7010,
#    'range_20_29': 8567,
#    'range_30_39': 4993,
#    'range_40_49': 3243,
#    'range_50_59': 1443,
#    'range_60_69': 376,
#    'range_70_79': 89,
#    'range_80_89': 14,
#    'range_90_99': 32,
#    'data_year': 2009},
#   {'unknown': 324,
#    'range_0_9': 74,
#    'range_10_19': 838,
#    'range_20_29': 746,
#    'range_30_39': 584,
#    'range_40_49': 373,
#    'range_50_59': 251,
#    'range_60_69': 118,
#    'range_70_79': 41,
#    'range_80_89': 10,
#    'range_90_99': 8,
#    'data_year': 2015},
#   {'unknown': 19367,
#    'range_0_9': 539,
#    'range_10_19': 36847,
#    'range_20_29': 66931,
#    'range_30_39': 36911,
#    'range_40_49': 25359,
#    'range_50_59': 11928,
#    'range_60_69': 3059,
#    'range_70_79': 813,
#    'range_80_89': 198,
#    'range_90_99': 148,
#    'data_year': 2010},
#   {'unknown': 14298,
#    'range_0_9': 111,
#    'range_10_19': 13706,
#    'range_20_29': 19743,
#    'range_30_39': 7287,
#    'range_40_49': 2606,
#    'range_50_59': 841,
#    'range_60_69': 86,
#    'range_70_79': 12,
#    'range_80_89': 5,
#    'range_90_99': 71,
#    'data_year': 2002},
#   {'unknown': 4760,
#    'range_0_9': 215,
#    'range_10_19': 8621,
#    'range_20_29': 9554,
#    'range_30_39': 6697,
#    'range_40_49': 3945,
#    'range_50_59': 2618,
#    'range_60_69': 817,
#    'range_70_79': 180,
#    'range_80_89': 47,
#    'range_90_99': 101,
#    'data_year': 2017},
#   {'unknown': 13,
#    'range_0_9': 6,
#    'range_10_19': 64,
#    'range_20_29': 72,
#    'range_30_39': 84,
#    'range_40_49': 43,
#    'range_50_59': 12,
#    'range_60_69': 16,
#    'range_70_79': 1,
#    'range_80_89': 0,
#    'range_90_99': 0,
#    'data_year': 1992},
#   {'unknown': 3898,
#    'range_0_9': 166,
#    'range_10_19': 6809,
#    'range_20_29': 8623,
#    'range_30_39': 5297,
#    'range_40_49': 3600,
#    'range_50_59': 1845,
#    'range_60_69': 466,
#    'range_70_79': 140,
#    'range_80_89': 38,
#    'range_90_99': 42,
#    'data_year': 2012},
#   {'unknown': 304,
#    'range_0_9': 89,
#    'range_10_19': 761,
#    'range_20_29': 709,
#    'range_30_39': 567,
#    'range_40_49': 363,
#    'range_50_59': 266,
#    'range_60_69': 106,
#    'range_70_79': 33,
#    'range_80_89': 8,
#    'range_90_99': 4,
#    'data_year': 2014},
#   {'unknown': 17301,
#    'range_0_9': 453,
#    'range_10_19': 26863,
#    'range_20_29': 63271,
#    'range_30_39': 39034,
#    'range_40_49': 24078,
#    'range_50_59': 13962,
#    'range_60_69': 3539,
#    'range_70_79': 861,
#    'range_80_89': 238,
#    'range_90_99': 164,
#    'data_year': 2013},
#   {'unknown': 6,
#    'range_0_9': 5,
#    'range_10_19': 41,
#    'range_20_29': 51,
#    'range_30_39': 41,
#    'range_40_49': 11,
#    'range_50_59': 3,
#    'range_60_69': 3,
#    'range_70_79': 1,
#    'range_80_89': 0,
#    'range_90_99': 0,
#    'data_year': 1991},
#   {'unknown': 3533,
#    'range_0_9': 132,
#    'range_10_19': 6576,
#    'range_20_29': 8286,
#    'range_30_39': 4844,
#    'range_40_49': 3144,
#    'range_50_59': 1211,
#    'range_60_69': 339,
#    'range_70_79': 94,
#    'range_80_89': 26,
#    'range_90_99': 25,
#    'data_year': 2007},
#   {'unknown': 25523,
#    'range_0_9': 175,
#    'range_10_19': 23332,
#    'range_20_29': 34502,
#    'range_30_39': 13517,
#    'range_40_49': 4574,
#    'range_50_59': 2419,
#    'range_60_69': 308,
#    'range_70_79': 41,
#    'range_80_89': 11,
#    'range_90_99': 142,
#    'data_year': 2016},
#   {'unknown': 3911,
#    'range_0_9': 30,
#    'range_10_19': 4510,
#    'range_20_29': 6449,
#    'range_30_39': 2341,
#    'range_40_49': 432,
#    'range_50_59': 47,
#    'range_60_69': 12,
#    'range_70_79': 1,
#    'range_80_89': 0,
#    'range_90_99': 50,
#    'data_year': 1994},
#   {'unknown': 1814,
#    'range_0_9': 111,
#    'range_10_19': 4117,
#    'range_20_29': 4636,
#    'range_30_39': 2908,
#    'range_40_49': 1450,
#    'range_50_59': 508,
#    'range_60_69': 151,
#    'range_70_79': 36,
#    'range_80_89': 6,
#    'range_90_99': 29,
#    'data_year': 2000},
#   {'unknown': 69,
#    'range_0_9': 1,
#    'range_10_19': 251,
#    'range_20_29': 328,
#    'range_30_39': 194,
#    'range_40_49': 84,
#    'range_50_59': 32,
#    'range_60_69': 15,
#    'range_70_79': 7,
#    'range_80_89': 4,
#    'range_90_99': 0,
#    'data_year': 1997},
#   {'unknown': 399,
#    'range_0_9': 36,
#    'range_10_19': 1380,
#    'range_20_29': 1762,
#    'range_30_39': 1176,
#    'range_40_49': 458,
#    'range_50_59': 178,
#    'range_60_69': 40,
#    'range_70_79': 10,
#    'range_80_89': 1,
#    'range_90_99': 14,
#    'data_year': 1996},
#   {'unknown': 651,
#    'range_0_9': 7,
#    'range_10_19': 673,
#    'range_20_29': 1416,
#    'range_30_39': 631,
#    'range_40_49': 393,
#    'range_50_59': 161,
#    'range_60_69': 43,
#    'range_70_79': 19,
#    'range_80_89': 10,
#    'range_90_99': 16,
#    'data_year': 2005},
#   {'unknown': 2349,
#    'range_0_9': 272,
#    'range_10_19': 12445,
#    'range_20_29': 15017,
#    'range_30_39': 10910,
#    'range_40_49': 4928,
#    'range_50_59': 1535,
#    'range_60_69': 525,
#    'range_70_79': 158,
#    'range_80_89': 30,
#    'range_90_99': 52,
#    'data_year': 1995},
#   {'unknown': 189,
#    'range_0_9': 153,
#    'range_10_19': 1154,
#    'range_20_29': 611,
#    'range_30_39': 561,
#    'range_40_49': 303,
#    'range_50_59': 137,
#    'range_60_69': 62,
#    'range_70_79': 17,
#    'range_80_89': 2,
#    'range_90_99': 4,
#    'data_year': 1999},
#   {'unknown': 186,
#    'range_0_9': 61,
#    'range_10_19': 633,
#    'range_20_29': 547,
#    'range_30_39': 489,
#    'range_40_49': 244,
#    'range_50_59': 96,
#    'range_60_69': 29,
#    'range_70_79': 14,
#    'range_80_89': 3,
#    'range_90_99': 2,
#    'data_year': 2001},
#   {'unknown': 92,
#    'range_0_9': 0,
#    'range_10_19': 249,
#    'range_20_29': 462,
#    'range_30_39': 238,
#    'range_40_49': 136,
#    'range_50_59': 69,
#    'range_60_69': 18,
#    'range_70_79': 8,
#    'range_80_89': 3,
#    'range_90_99': 0,
#    'data_year': 1998},
#   {'unknown': 14451,
#    'range_0_9': 143,
#    'range_10_19': 13470,
#    'range_20_29': 20238,
#    'range_30_39': 7338,
#    'range_40_49': 2968,
#    'range_50_59': 653,
#    'range_60_69': 81,
#    'range_70_79': 12,
#    'range_80_89': 3,
#    'range_90_99': 66,
#    'data_year': 2003},
#   {'unknown': 17795,
#    'range_0_9': 162,
#    'range_10_19': 7917,
#    'range_20_29': 13068,
#    'range_30_39': 9560,
#    'range_40_49': 3535,
#    'range_50_59': 1211,
#    'range_60_69': 507,
#    'range_70_79': 157,
#    'range_80_89': 32,
#    'range_90_99': 37,
#    'data_year': 1991},
#   {'unknown': 578,
#    'range_0_9': 2,
#    'range_10_19': 609,
#    'range_20_29': 1577,
#    'range_30_39': 752,
#    'range_40_49': 418,
#    'range_50_59': 231,
#    'range_60_69': 90,
#    'range_70_79': 34,
#    'range_80_89': 16,
#    'range_90_99': 10,
#    'data_year': 2012},
#   {'unknown': 13218,
#    'range_0_9': 583,
#    'range_10_19': 29330,
#    'range_20_29': 40614,
#    'range_30_39': 26381,
#    'range_40_49': 15735,
#    'range_50_59': 5151,
#    'range_60_69': 1418,
#    'range_70_79': 452,
#    'range_80_89': 89,
#    'range_90_99': 189,
#    'data_year': 2001},
#   {'unknown': 26637,
#    'range_0_9': 162,
#    'range_10_19': 31563,
#    'range_20_29': 40138,
#    'range_30_39': 11084,
#    'range_40_49': 5293,
#    'range_50_59': 1656,
#    'range_60_69': 153,
#    'range_70_79': 20,
#    'range_80_89': 9,
#    'range_90_99': 254,
#    'data_year': 2009},
#   {'unknown': 777,
#    'range_0_9': 2,
#    'range_10_19': 911,
#    'range_20_29': 2083,
#    'range_30_39': 1112,
#    'range_40_49': 568,
#    'range_50_59': 307,
#    'range_60_69': 93,
#    'range_70_79': 33,
#    'range_80_89': 15,
#    'range_90_99': 6,
#    'data_year': 2017},
#   {'unknown': 383,
#    'range_0_9': 190,
#    'range_10_19': 1950,
#    'range_20_29': 910,
#    'range_30_39': 806,
#    'range_40_49': 544,
#    'range_50_59': 215,
#    'range_60_69': 88,
#    'range_70_79': 15,
#    'range_80_89': 5,
#    'range_90_99': 2,
#    'data_year': 2004},
#   {'unknown': 27109,
#    'range_0_9': 264,
#    'range_10_19': 29760,
#    'range_20_29': 38425,
#    'range_30_39': 12243,
#    'range_40_49': 5973,
#    'range_50_59': 1324,
#    'range_60_69': 145,
#    'range_70_79': 25,
#    'range_80_89': 13,
#    'range_90_99': 116,
#    'data_year': 2006},
#   {'unknown': 30,
#    'range_0_9': 20,
#    'range_10_19': 156,
#    'range_20_29': 133,
#    'range_30_39': 117,
#    'range_40_49': 59,
#    'range_50_59': 28,
#    'range_60_69': 6,
#    'range_70_79': 5,
#    'range_80_89': 1,
#    'range_90_99': 0,
#    'data_year': 1995},
#   {'unknown': 509,
#    'range_0_9': 7,
#    'range_10_19': 922,
#    'range_20_29': 1585,
#    'range_30_39': 600,
#    'range_40_49': 416,
#    'range_50_59': 198,
#    'range_60_69': 53,
#    'range_70_79': 11,
#    'range_80_89': 7,
#    'range_90_99': 5,
#    'data_year': 2007},
#   {'unknown': 269,
#    'range_0_9': 7,
#    'range_10_19': 350,
#    'range_20_29': 702,
#    'range_30_39': 331,
#    'range_40_49': 191,
#    'range_50_59': 86,
#    'range_60_69': 27,
#    'range_70_79': 18,
#    'range_80_89': 3,
#    'range_90_99': 4,
#    'data_year': 2000},
#   {'unknown': 674,
#    'range_0_9': 59,
#    'range_10_19': 1975,
#    'range_20_29': 2322,
#    'range_30_39': 1623,
#    'range_40_49': 663,
#    'range_50_59': 263,
#    'range_60_69': 68,
#    'range_70_79': 16,
#    'range_80_89': 6,
#    'range_90_99': 17,
#    'data_year': 1997},
#   {'unknown': 18969,
#    'range_0_9': 391,
#    'range_10_19': 26851,
#    'range_20_29': 65722,
#    'range_30_39': 43976,
#    'range_40_49': 25175,
#    'range_50_59': 15581,
#    'range_60_69': 4337,
#    'range_70_79': 1026,
#    'range_80_89': 217,
#    'range_90_99': 177,
#    'data_year': 2015},
#   {'unknown': 3237,
#    'range_0_9': 153,
#    'range_10_19': 6238,
#    'range_20_29': 7736,
#    'range_30_39': 4634,
#    'range_40_49': 2875,
#    'range_50_59': 1002,
#    'range_60_69': 289,
#    'range_70_79': 77,
#    'range_80_89': 14,
#    'range_90_99': 30,
#    'data_year': 2005},
#   {'unknown': 38,
#    'range_0_9': 34,
#    'range_10_19': 239,
#    'range_20_29': 190,
#    'range_30_39': 174,
#    'range_40_49': 57,
#    'range_50_59': 24,
#    'range_60_69': 12,
#    'range_70_79': 2,
#    'range_80_89': 0,
#    'range_90_99': 0,
#    'data_year': 1993},
#   {'unknown': 244,
#    'range_0_9': 92,
#    'range_10_19': 761,
#    'range_20_29': 672,
#    'range_30_39': 511,
#    'range_40_49': 398,
#    'range_50_59': 190,
#    'range_60_69': 81,
#    'range_70_79': 21,
#    'range_80_89': 7,
#    'range_90_99': 2,
#    'data_year': 2010},
#   {'unknown': 27933,
#    'range_0_9': 176,
#    'range_10_19': 34157,
#    'range_20_29': 39809,
#    'range_30_39': 11472,
#    'range_40_49': 5610,
#    'range_50_59': 1497,
#    'range_60_69': 147,
#    'range_70_79': 25,
#    'range_80_89': 14,
#    'range_90_99': 233,
#    'data_year': 2008},
#   {'unknown': 44,
#    'range_0_9': 0,
#    'range_10_19': 179,
#    'range_20_29': 284,
#    'range_30_39': 151,
#    'range_40_49': 87,
#    'range_50_59': 27,
#    'range_60_69': 14,
#    'range_70_79': 8,
#    'range_80_89': 1,
#    'range_90_99': 0,
#    'data_year': 1996},
#   {'unknown': 17675,
#    'range_0_9': 420,
#    'range_10_19': 26478,
#    'range_20_29': 63741,
#    'range_30_39': 40618,
#    'range_40_49': 24656,
#    'range_50_59': 14812,
#    'range_60_69': 3924,
#    'range_70_79': 952,
#    'range_80_89': 240,
#    'range_90_99': 111,
#    'data_year': 2014},
#   {'unknown': 261,
#    'range_0_9': 85,
#    'range_10_19': 685,
#    'range_20_29': 692,
#    'range_30_39': 560,
#    'range_40_49': 387,
#    'range_50_59': 249,
#    'range_60_69': 78,
#    'range_70_79': 36,
#    'range_80_89': 4,
#    'range_90_99': 2,
#    'data_year': 2013},
#   {'unknown': 1115,
#    'range_0_9': 86,
#    'range_10_19': 2862,
#    'range_20_29': 3144,
#    'range_30_39': 2136,
#    'range_40_49': 979,
#    'range_50_59': 304,
#    'range_60_69': 95,
#    'range_70_79': 34,
#    'range_80_89': 1,
#    'range_90_99': 53,
#    'data_year': 1998},
#   {'unknown': 8336,
#    'range_0_9': 254,
#    'range_10_19': 11240,
#    'range_20_29': 17609,
#    'range_30_39': 12014,
#    'range_40_49': 4725,
#    'range_50_59': 1605,
#    'range_60_69': 633,
#    'range_70_79': 210,
#    'range_80_89': 43,
#    'range_90_99': 25,
#    'data_year': 1992},
#   {'unknown': 26204,
#    'range_0_9': 135,
#    'range_10_19': 26921,
#    'range_20_29': 37792,
#    'range_30_39': 11153,
#    'range_40_49': 4958,
#    'range_50_59': 1643,
#    'range_60_69': 218,
#    'range_70_79': 22,
#    'range_80_89': 8,
#    'range_90_99': 127,
#    'data_year': 2011},
#   {'unknown': 6816,
#    'range_0_9': 505,
#    'range_10_19': 21802,
#    'range_20_29': 25606,
#    'range_30_39': 18393,
#    'range_40_49': 9473,
#    'range_50_59': 2803,
#    'range_60_69': 903,
#    'range_70_79': 306,
#    'range_80_89': 71,
#    'range_90_99': 159,
#    'data_year': 1998},
#   {'unknown': 561,
#    'range_0_9': 15,
#    'range_10_19': 938,
#    'range_20_29': 1534,
#    'range_30_39': 1043,
#    'range_40_49': 347,
#    'range_50_59': 92,
#    'range_60_69': 32,
#    'range_70_79': 7,
#    'range_80_89': 2,
#    'range_90_99': 5,
#    'data_year': 1992},
#   {'unknown': 422,
#    'range_0_9': 87,
#    'range_10_19': 941,
#    'range_20_29': 759,
#    'range_30_39': 652,
#    'range_40_49': 437,
#    'range_50_59': 335,
#    'range_60_69': 101,
#    'range_70_79': 48,
#    'range_80_89': 11,
#    'range_90_99': 8,
#    'data_year': 2017},
#   {'unknown': 307,
#    'range_0_9': 91,
#    'range_10_19': 773,
#    'range_20_29': 772,
#    'range_30_39': 577,
#    'range_40_49': 411,
#    'range_50_59': 240,
#    'range_60_69': 102,
#    'range_70_79': 27,
#    'range_80_89': 6,
#    'range_90_99': 2,
#    'data_year': 2012},
#   {'unknown': 32,
#    'range_0_9': 1,
#    'range_10_19': 137,
#    'range_20_29': 214,
#    'range_30_39': 135,
#    'range_40_49': 62,
#    'range_50_59': 21,
#    'range_60_69': 11,
#    'range_70_79': 6,
#    'range_80_89': 2,
#    'range_90_99': 0,
#    'data_year': 1995},
#   {'unknown': 3517,
#    'range_0_9': 155,
#    'range_10_19': 6705,
#    'range_20_29': 8165,
#    'range_30_39': 5300,
#    'range_40_49': 3377,
#    'range_50_59': 2036,
#    'range_60_69': 544,
#    'range_70_79': 142,
#    'range_80_89': 19,
#    'range_90_99': 71,
#    'data_year': 2014},
#   {'unknown': 524,
#    'range_0_9': 257,
#    'range_10_19': 2561,
#    'range_20_29': 1477,
#    'range_30_39': 1144,
#    'range_40_49': 840,
#    'range_50_59': 481,
#    'range_60_69': 157,
#    'range_70_79': 49,
#    'range_80_89': 7,
#    'range_90_99': 4,
#    'data_year': 2011},
#   {'unknown': 3944,
#    'range_0_9': 185,
#    'range_10_19': 7480,
#    'range_20_29': 8818,
#    'range_30_39': 5824,
#    'range_40_49': 3676,
#    'range_50_59': 2267,
#    'range_60_69': 633,
#    'range_70_79': 154,
#    'range_80_89': 28,
#    'range_90_99': 87,
#    'data_year': 2015},
#   {'unknown': 4628,
#    'range_0_9': 404,
#    'range_10_19': 18717,
#    'range_20_29': 21848,
#    'range_30_39': 15874,
#    'range_40_49': 7720,
#    'range_50_59': 2403,
#    'range_60_69': 775,
#    'range_70_79': 214,
#    'range_80_89': 49,
#    'range_90_99': 108,
#    'data_year': 1997},
#   {'unknown': 18814,
#    'range_0_9': 614,
#    'range_10_19': 42136,
#    'range_20_29': 59281,
#    'range_30_39': 34415,
#    'range_40_49': 23847,
#    'range_50_59': 8350,
#    'range_60_69': 2132,
#    'range_70_79': 641,
#    'range_80_89': 142,
#    'range_90_99': 171,
#    'data_year': 2005},
#   {'unknown': 464,
#    'range_0_9': 211,
#    'range_10_19': 2203,
#    'range_20_29': 1211,
#    'range_30_39': 895,
#    'range_40_49': 654,
#    'range_50_59': 319,
#    'range_60_69': 116,
#    'range_70_79': 31,
#    'range_80_89': 4,
#    'range_90_99': 12,
#    'data_year': 2008},
#   {'unknown': 4422,
#    'range_0_9': 23,
#    'range_10_19': 4050,
#    'range_20_29': 6528,
#    'range_30_39': 2427,
#    'range_40_49': 384,
#    'range_50_59': 66,
#    'range_60_69': 8,
#    'range_70_79': 2,
#    'range_80_89': 0,
#    'range_90_99': 51,
#    'data_year': 1993},
#   {'unknown': 17234,
#    'range_0_9': 190,
#    'range_10_19': 15667,
#    'range_20_29': 22971,
#    'range_30_39': 8850,
#    'range_40_49': 4132,
#    'range_50_59': 912,
#    'range_60_69': 102,
#    'range_70_79': 16,
#    'range_80_89': 1,
#    'range_90_99': 100,
#    'data_year': 2004},
#   {'unknown': 502,
#    'range_0_9': 196,
#    'range_10_19': 2238,
#    'range_20_29': 1347,
#    'range_30_39': 991,
#    'range_40_49': 772,
#    'range_50_59': 403,
#    'range_60_69': 127,
#    'range_70_79': 28,
#    'range_80_89': 9,
#    'range_90_99': 8,
#    'data_year': 2009},
#   {'unknown': 537,
#    'range_0_9': 0,
#    'range_10_19': 553,
#    'range_20_29': 1592,
#    'range_30_39': 710,
#    'range_40_49': 415,
#    'range_50_59': 263,
#    'range_60_69': 91,
#    'range_70_79': 22,
#    'range_80_89': 14,
#    'range_90_99': 6,
#    'data_year': 2013},
#   {'unknown': 2017,
#    'range_0_9': 113,
#    'range_10_19': 4730,
#    'range_20_29': 5115,
#    'range_30_39': 3185,
#    'range_40_49': 1749,
#    'range_50_59': 613,
#    'range_60_69': 176,
#    'range_70_79': 51,
#    'range_80_89': 10,
#    'range_90_99': 26,
#    'data_year': 2001},
#   {'unknown': 495,
#    'range_0_9': 256,
#    'range_10_19': 2305,
#    'range_20_29': 1237,
#    'range_30_39': 958,
#    'range_40_49': 676,
#    'range_50_59': 287,
#    'range_60_69': 100,
#    'range_70_79': 30,
#    'range_80_89': 7,
#    'range_90_99': 7,
#    'data_year': 2006},
#   {'unknown': 1060,
#    'range_0_9': 11,
#    'range_10_19': 691,
#    'range_20_29': 1118,
#    'range_30_39': 811,
#    'range_40_49': 221,
#    'range_50_59': 83,
#    'range_60_69': 17,
#    'range_70_79': 8,
#    'range_80_89': 1,
#    'range_90_99': 6,
#    'data_year': 1991},
#   {'unknown': 274,
#    'range_0_9': 107,
#    'range_10_19': 752,
#    'range_20_29': 710,
#    'range_30_39': 540,
#    'range_40_49': 358,
#    'range_50_59': 189,
#    'range_60_69': 64,
#    'range_70_79': 31,
#    'range_80_89': 2,
#    'range_90_99': 5,
#    'data_year': 2007},
#   {'unknown': 332,
#    'range_0_9': 235,
#    'range_10_19': 1733,
#    'range_20_29': 812,
#    'range_30_39': 752,
#    'range_40_49': 465,
#    'range_50_59': 179,
#    'range_60_69': 73,
#    'range_70_79': 20,
#    'range_80_89': 6,
#    'range_90_99': 3,
#    'data_year': 2003},
#   {'unknown': 211,
#    'range_0_9': 77,
#    'range_10_19': 628,
#    'range_20_29': 540,
#    'range_30_39': 436,
#    'range_40_49': 281,
#    'range_50_59': 100,
#    'range_60_69': 53,
#    'range_70_79': 12,
#    'range_80_89': 0,
#    'range_90_99': 5,
#    'data_year': 2000},
#   {'unknown': 37,
#    'range_0_9': 26,
#    'range_10_19': 203,
#    'range_20_29': 178,
#    'range_30_39': 174,
#    'range_40_49': 79,
#    'range_50_59': 38,
#    'range_60_69': 22,
#    'range_70_79': 8,
#    'range_80_89': 2,
#    'range_90_99': 0,
#    'data_year': 1996},
#   {'unknown': 540,
#    'range_0_9': 1,
#    'range_10_19': 688,
#    'range_20_29': 1474,
#    'range_30_39': 690,
#    'range_40_49': 401,
#    'range_50_59': 229,
#    'range_60_69': 71,
#    'range_70_79': 24,
#    'range_80_89': 7,
#    'range_90_99': 4,
#    'data_year': 2010},
#   {'unknown': 135,
#    'range_0_9': 0,
#    'range_10_19': 186,
#    'range_20_29': 311,
#    'range_30_39': 165,
#    'range_40_49': 96,
#    'range_50_59': 34,
#    'range_60_69': 20,
#    'range_70_79': 7,
#    'range_80_89': 1,
#    'range_90_99': 0,
#    'data_year': 1992},
#   {'unknown': 5953,
#    'range_0_9': 71,
#    'range_10_19': 7487,
#    'range_20_29': 9588,
#    'range_30_39': 3985,
#    'range_40_49': 1274,
#    'range_50_59': 332,
#    'range_60_69': 20,
#    'range_70_79': 10,
#    'range_80_89': 1,
#    'range_90_99': 61,
#    'data_year': 1999},
#   {'unknown': 299,
#    'range_0_9': 20,
#    'range_10_19': 1017,
#    'range_20_29': 1350,
#    'range_30_39': 937,
#    'range_40_49': 401,
#    'range_50_59': 110,
#    'range_60_69': 35,
#    'range_70_79': 9,
#    'range_80_89': 2,
#    'range_90_99': 10,
#    'data_year': 1995},
#   {'unknown': 516,
#    'range_0_9': 4,
#    'range_10_19': 656,
#    'range_20_29': 1677,
#    'range_30_39': 745,
#    'range_40_49': 416,
#    'range_50_59': 280,
#    'range_60_69': 94,
#    'range_70_79': 24,
#    'range_80_89': 14,
#    'range_90_99': 2,
#    'data_year': 2014},
#   {'unknown': 631,
#    'range_0_9': 278,
#    'range_10_19': 2983,
#    'range_20_29': 1823,
#    'range_30_39': 1495,
#    'range_40_49': 943,
#    'range_50_59': 630,
#    'range_60_69': 247,
#    'range_70_79': 68,
#    'range_80_89': 12,
#    'range_90_99': 13,
#    'data_year': 2016},
#   {'unknown': 41,
#    'range_0_9': 32,
#    'range_10_19': 280,
#    'range_20_29': 213,
#    'range_30_39': 161,
#    'range_40_49': 83,
#    'range_50_59': 21,
#    'range_60_69': 3,
#    'range_70_79': 1,
#    'range_80_89': 0,
#    'range_90_99': 0,
#    'data_year': 1994},
#   {'unknown': 659,
#    'range_0_9': 3,
#    'range_10_19': 686,
#    'range_20_29': 1870,
#    'range_30_39': 881,
#    'range_40_49': 436,
#    'range_50_59': 299,
#    'range_60_69': 83,
#    'range_70_79': 42,
#    'range_80_89': 14,
#    'range_90_99': 5,
#    'data_year': 2015},
#   {'unknown': 3494,
#    'range_0_9': 330,
#    'range_10_19': 15409,
#    'range_20_29': 17958,
#    'range_30_39': 13092,
#    'range_40_49': 6182,
#    'range_50_59': 2027,
#    'range_60_69': 658,
#    'range_70_79': 195,
#    'range_80_89': 39,
#    'range_90_99': 48,
#    'data_year': 1996},
#   {'unknown': 20358,
#    'range_0_9': 677,
#    'range_10_19': 43359,
#    'range_20_29': 65424,
#    'range_30_39': 35817,
#    'range_40_49': 25733,
#    'range_50_59': 9858,
#    'range_60_69': 2389,
#    'range_70_79': 660,
#    'range_80_89': 181,
#    'range_90_99': 169,
#    'data_year': 2007},
#   {'unknown': 12094,
#    'range_0_9': 589,
#    'range_10_19': 27812,
#    'range_20_29': 37109,
#    'range_30_39': 25315,
#    'range_40_49': 14575,
#    'range_50_59': 4607,
#    'range_60_69': 1328,
#    'range_70_79': 420,
#    'range_80_89': 89,
#    'range_90_99': 195,
#    'data_year': 2000},
#   {'unknown': 3381,
#    'range_0_9': 123,
#    'range_10_19': 6589,
#    'range_20_29': 8042,
#    'range_30_39': 5260,
#    'range_40_49': 3349,
#    'range_50_59': 1844,
#    'range_60_69': 491,
#    'range_70_79': 135,
#    'range_80_89': 37,
#    'range_90_99': 63,
#    'data_year': 2013},
#   {'unknown': 18524,
#    'range_0_9': 475,
#    'range_10_19': 31143,
#    'range_20_29': 66626,
#    'range_30_39': 39217,
#    'range_40_49': 25926,
#    'range_50_59': 14078,
#    'range_60_69': 3536,
#    'range_70_79': 808,
#    'range_80_89': 194,
#    'range_90_99': 143,
#    'data_year': 2012},
#   {'unknown': 111,
#    'range_0_9': 46,
#    'range_10_19': 362,
#    'range_20_29': 300,
#    'range_30_39': 312,
#    'range_40_49': 170,
#    'range_50_59': 90,
#    'range_60_69': 29,
#    'range_70_79': 20,
#    'range_80_89': 4,
#    'range_90_99': 5,
#    'data_year': 1998},
#   {'unknown': 22446,
#    'range_0_9': 431,
#    'range_10_19': 29183,
#    'range_20_29': 69810,
#    'range_30_39': 51290,
#    'range_40_49': 27585,
#    'range_50_59': 17379,
#    'range_60_69': 5325,
#    'range_70_79': 1185,
#    'range_80_89': 249,
#    'range_90_99': 159,
#    'data_year': 2017},
#   {'unknown': 222,
#    'range_0_9': 0,
#    'range_10_19': 427,
#    'range_20_29': 860,
#    'range_30_39': 349,
#    'range_40_49': 223,
#    'range_50_59': 99,
#    'range_60_69': 36,
#    'range_70_79': 11,
#    'range_80_89': 10,
#    'range_90_99': 5,
#    'data_year': 2001},
#   {'unknown': 369,
#    'range_0_9': 0,
#    'range_10_19': 162,
#    'range_20_29': 270,
#    'range_30_39': 192,
#    'range_40_49': 91,
#    'range_50_59': 21,
#    'range_60_69': 11,
#    'range_70_79': 4,
#    'range_80_89': 3,
#    'range_90_99': 0,
#    'data_year': 1991},
#   {'unknown': 98,
#    'range_0_9': 36,
#    'range_10_19': 295,
#    'range_20_29': 234,
#    'range_30_39': 222,
#    'range_40_49': 126,
#    'range_50_59': 64,
#    'range_60_69': 26,
#    'range_70_79': 9,
#    'range_80_89': 1,
#    'range_90_99': 0,
#    'data_year': 1997},
#   {'unknown': 300,
#    'range_0_9': 219,
#    'range_10_19': 1704,
#    'range_20_29': 803,
#    'range_30_39': 799,
#    'range_40_49': 455,
#    'range_50_59': 163,
#    'range_60_69': 58,
#    'range_70_79': 16,
#    'range_80_89': 2,
#    'range_90_99': 8,
#    'data_year': 2002},
#   {'unknown': 291,
#    'range_0_9': 85,
#    'range_10_19': 892,
#    'range_20_29': 767,
#    'range_30_39': 556,
#    'range_40_49': 344,
#    'range_50_59': 159,
#    'range_60_69': 72,
#    'range_70_79': 30,
#    'range_80_89': 3,
#    'range_90_99': 3,
#    'data_year': 2005},
#   {'unknown': 3652,
#    'range_0_9': 136,
#    'range_10_19': 6900,
#    'range_20_29': 8519,
#    'range_30_39': 5139,
#    'range_40_49': 3435,
#    'range_50_59': 1553,
#    'range_60_69': 411,
#    'range_70_79': 104,
#    'range_80_89': 20,
#    'range_90_99': 27,
#    'data_year': 2010},
#   {'unknown': 19479,
#    'range_0_9': 510,
#    'range_10_19': 39349,
#    'range_20_29': 66488,
#    'range_30_39': 36237,
#    'range_40_49': 25210,
#    'range_50_59': 10836,
#    'range_60_69': 2724,
#    'range_70_79': 720,
#    'range_80_89': 151,
#    'range_90_99': 160,
#    'data_year': 2009},
#   {'unknown': 14232,
#    'range_0_9': 72,
#    'range_10_19': 13053,
#    'range_20_29': 18749,
#    'range_30_39': 6837,
#    'range_40_49': 2381,
#    'range_50_59': 970,
#    'range_60_69': 69,
#    'range_70_79': 5,
#    'range_80_89': 6,
#    'range_90_99': 44,
#    'data_year': 2001},
#   {'unknown': 21537,
#    'range_0_9': 622,
#    'range_10_19': 43853,
#    'range_20_29': 62903,
#    'range_30_39': 34070,
#    'range_40_49': 24868,
#    'range_50_59': 9008,
#    'range_60_69': 2199,
#    'range_70_79': 661,
#    'range_80_89': 152,
#    'range_90_99': 148,
#    'data_year': 2006},
#   {'unknown': 2967,
#    'range_0_9': 142,
#    'range_10_19': 5657,
#    'range_20_29': 7068,
#    'range_30_39': 4104,
#    'range_40_49': 2494,
#    'range_50_59': 852,
#    'range_60_69': 256,
#    'range_70_79': 64,
#    'range_80_89': 15,
#    'range_90_99': 28,
#    'data_year': 2004},
#   {'unknown': 12702,
#    'range_0_9': 521,
#    'range_10_19': 30527,
#    'range_20_29': 43024,
#    'range_30_39': 26287,
#    'range_40_49': 17744,
#    'range_50_59': 5743,
#    'range_60_69': 1542,
#    'range_70_79': 464,
#    'range_80_89': 123,
#    'range_90_99': 132,
#    'data_year': 2003},
#   {'unknown': 313,
#    'range_0_9': 77,
#    'range_10_19': 860,
#    'range_20_29': 730,
#    'range_30_39': 653,
#    'range_40_49': 399,
#    'range_50_59': 246,
#    'range_60_69': 117,
#    'range_70_79': 38,
#    'range_80_89': 8,
#    'range_90_99': 4,
#    'data_year': 2016},
#   {'unknown': 54,
#    'range_0_9': 19,
#    'range_10_19': 106,
#    'range_20_29': 112,
#    'range_30_39': 118,
#    'range_40_49': 44,
#    'range_50_59': 26,
#    'range_60_69': 16,
#    'range_70_79': 4,
#    'range_80_89': 1,
#    'range_90_99': 0,
#    'data_year': 1994},
#   {'unknown': 6499,
#    'range_0_9': 10,
#    'range_10_19': 2406,
#    'range_20_29': 5065,
#    'range_30_39': 2080,
#    'range_40_49': 372,
#    'range_50_59': 61,
#    'range_60_69': 15,
#    'range_70_79': 5,
#    'range_80_89': 4,
#    'range_90_99': 16,
#    'data_year': 1991},
#   {'unknown': 182,
#    'range_0_9': 127,
#    'range_10_19': 918,
#    'range_20_29': 502,
#    'range_30_39': 532,
#    'range_40_49': 286,
#    'range_50_59': 123,
#    'range_60_69': 43,
#    'range_70_79': 13,
#    'range_80_89': 1,
#    'range_90_99': 8,
#    'data_year': 1998},
#   {'unknown': 24509,
#    'range_0_9': 114,
#    'range_10_19': 22844,
#    'range_20_29': 34385,
#    'range_30_39': 11693,
#    'range_40_49': 4247,
#    'range_50_59': 1984,
#    'range_60_69': 250,
#    'range_70_79': 25,
#    'range_80_89': 6,
#    'range_90_99': 109,
#    'data_year': 2014},
#   {'unknown': 18546,
#    'range_0_9': 511,
#    'range_10_19': 33124,
#    'range_20_29': 65146,
#    'range_30_39': 36765,
#    'range_40_49': 24416,
#    'range_50_59': 12576,
#    'range_60_69': 3273,
#    'range_70_79': 790,
#    'range_80_89': 197,
#    'range_90_99': 109,
#    'data_year': 2011},
#   {'unknown': 97,
#    'range_0_9': 2,
#    'range_10_19': 299,
#    'range_20_29': 536,
#    'range_30_39': 280,
#    'range_40_49': 155,
#    'range_50_59': 68,
#    'range_60_69': 26,
#    'range_70_79': 14,
#    'range_80_89': 3,
#    'range_90_99': 1,
#    'data_year': 1999},
#   {'unknown': 4258,
#    'range_0_9': 19,
#    'range_10_19': 3646,
#    'range_20_29': 6575,
#    'range_30_39': 2600,
#    'range_40_49': 401,
#    'range_50_59': 88,
#    'range_60_69': 13,
#    'range_70_79': 7,
#    'range_80_89': 1,
#    'range_90_99': 17,
#    'data_year': 1992},
#   {'unknown': 231,
#    'range_0_9': 57,
#    'range_10_19': 750,
#    'range_20_29': 595,
#    'range_30_39': 486,
#    'range_40_49': 296,
#    'range_50_59': 119,
#    'range_60_69': 46,
#    'range_70_79': 15,
#    'range_80_89': 5,
#    'range_90_99': 2,
#    'data_year': 2002},
#   {'unknown': 110,
#    'range_0_9': 114,
#    'range_10_19': 717,
#    'range_20_29': 406,
#    'range_30_39': 388,
#    'range_40_49': 215,
#    'range_50_59': 82,
#    'range_60_69': 28,
#    'range_70_79': 3,
#    'range_80_89': 1,
#    'range_90_99': 2,
#    'data_year': 1997},
#   {'unknown': 589,
#    'range_0_9': 23,
#    'range_10_19': 1147,
#    'range_20_29': 1668,
#    'range_30_39': 1053,
#    'range_40_49': 394,
#    'range_50_59': 122,
#    'range_60_69': 41,
#    'range_70_79': 16,
#    'range_80_89': 0,
#    'range_90_99': 11,
#    'data_year': 1993},
#   {'unknown': 415,
#    'range_0_9': 239,
#    'range_10_19': 2013,
#    'range_20_29': 1030,
#    'range_30_39': 842,
#    'range_40_49': 654,
#    'range_50_59': 237,
#    'range_60_69': 99,
#    'range_70_79': 36,
#    'range_80_89': 4,
#    'range_90_99': 4,
#    'data_year': 2005},
#   {'unknown': 19564,
#    'range_0_9': 597,
#    'range_10_19': 42341,
#    'range_20_29': 65354,
#    'range_30_39': 35050,
#    'range_40_49': 25417,
#    'range_50_59': 10361,
#    'range_60_69': 2604,
#    'range_70_79': 654,
#    'range_80_89': 172,
#    'range_90_99': 155,
#    'data_year': 2008},
#   {'unknown': 25451,
#    'range_0_9': 104,
#    'range_10_19': 22710,
#    'range_20_29': 34925,
#    'range_30_39': 12630,
#    'range_40_49': 4512,
#    'range_50_59': 2056,
#    'range_60_69': 268,
#    'range_70_79': 17,
#    'range_80_89': 10,
#    'range_90_99': 223,
#    'data_year': 2015},
#   {'unknown': 234,
#    'range_0_9': 71,
#    'range_10_19': 751,
#    'range_20_29': 690,
#    'range_30_39': 567,
#    'range_40_49': 365,
#    'range_50_59': 213,
#    'range_60_69': 80,
#    'range_70_79': 28,
#    'range_80_89': 6,
#    'range_90_99': 7,
#    'data_year': 2011},
#   {'unknown': 720,
#    'range_0_9': 257,
#    'range_10_19': 2819,
#    'range_20_29': 1772,
#    'range_30_39': 1525,
#    'range_40_49': 952,
#    'range_50_59': 668,
#    'range_60_69': 235,
#    'range_70_79': 62,
#    'range_80_89': 13,
#    'range_90_99': 13,
#    'data_year': 2017},
#   {'unknown': 548,
#    'range_0_9': 253,
#    'range_10_19': 2603,
#    'range_20_29': 1650,
#    'range_30_39': 1217,
#    'range_40_49': 823,
#    'range_50_59': 540,
#    'range_60_69': 170,
#    'range_70_79': 45,
#    'range_80_89': 24,
#    'range_90_99': 16,
#    'data_year': 2012},
#   {'unknown': 25414,
#    'range_0_9': 98,
#    'range_10_19': 24040,
#    'range_20_29': 36600,
#    'range_30_39': 11601,
#    'range_40_49': 4600,
#    'range_50_59': 1964,
#    'range_60_69': 235,
#    'range_70_79': 23,
#    'range_80_89': 10,
#    'range_90_99': 310,
#    'data_year': 2013},
#   {'unknown': 348,
#    'range_0_9': 2,
#    'range_10_19': 467,
#    'range_20_29': 1037,
#    'range_30_39': 428,
#    'range_40_49': 309,
#    'range_50_59': 103,
#    'range_60_69': 44,
#    'range_70_79': 17,
#    'range_80_89': 9,
#    'range_90_99': 2,
#    'data_year': 2004},
#   {'unknown': 301,
#    'range_0_9': 77,
#    'range_10_19': 852,
#    'range_20_29': 739,
#    'range_30_39': 505,
#    'range_40_49': 357,
#    'range_50_59': 204,
#    'range_60_69': 60,
#    'range_70_79': 25,
#    'range_80_89': 8,
#    'range_90_99': 6,
#    'data_year': 2008},
#   {'unknown': 26719,
#    'range_0_9': 145,
#    'range_10_19': 29057,
#    'range_20_29': 40066,
#    'range_30_39': 11017,
#    'range_40_49': 5102,
#    'range_50_59': 1713,
#    'range_60_69': 200,
#    'range_70_79': 14,
#    'range_80_89': 9,
#    'range_90_99': 159,
#    'data_year': 2010},
#   {'unknown': 13015,
#    'range_0_9': 546,
#    'range_10_19': 30952,
#    'range_20_29': 43506,
#    'range_30_39': 27418,
#    'range_40_49': 17323,
#    'range_50_59': 5550,
#    'range_60_69': 1488,
#    'range_70_79': 439,
#    'range_80_89': 108,
#    'range_90_99': 160,
#    'data_year': 2002},
#   {'unknown': 1604,
#    'range_0_9': 16,
#    'range_10_19': 3637,
#    'range_20_29': 4484,
#    'range_30_39': 1763,
#    'range_40_49': 420,
#    'range_50_59': 65,
#    'range_60_69': 10,
#    'range_70_79': 2,
#    'range_80_89': 1,
#    'range_90_99': 38,
#    'data_year': 1995},
#   {'unknown': 269,
#    'range_0_9': 75,
#    'range_10_19': 832,
#    'range_20_29': 675,
#    'range_30_39': 554,
#    'range_40_49': 369,
#    'range_50_59': 181,
#    'range_60_69': 65,
#    'range_70_79': 19,
#    'range_80_89': 9,
#    'range_90_99': 3,
#    'data_year': 2006},
#   {'unknown': 1282,
#    'range_0_9': 89,
#    'range_10_19': 3117,
#    'range_20_29': 3434,
#    'range_30_39': 2321,
#    'range_40_49': 1081,
#    'range_50_59': 397,
#    'range_60_69': 127,
#    'range_70_79': 30,
#    'range_80_89': 7,
#    'range_90_99': 31,
#    'data_year': 1999},
#   {'unknown': 217,
#    'range_0_9': 79,
#    'range_10_19': 741,
#    'range_20_29': 688,
#    'range_30_39': 523,
#    'range_40_49': 333,
#    'range_50_59': 213,
#    'range_60_69': 77,
#    'range_70_79': 27,
#    'range_80_89': 4,
#    'range_90_99': 4,
#    'data_year': 2009},
#   {'unknown': 21295,
#    'range_0_9': 503,
#    'range_10_19': 28272,
#    'range_20_29': 69278,
#    'range_30_39': 47965,
#    'range_40_49': 26861,
#    'range_50_59': 16720,
#    'range_60_69': 4942,
#    'range_70_79': 1131,
#    'range_80_89': 273,
#    'range_90_99': 113,
#    'data_year': 2016},
#   {'unknown': 4534,
#    'range_0_9': 285,
#    'range_10_19': 14279,
#    'range_20_29': 17103,
#    'range_30_39': 11411,
#    'range_40_49': 4673,
#    'range_50_59': 1486,
#    'range_60_69': 550,
#    'range_70_79': 178,
#    'range_80_89': 31,
#    'range_90_99': 31,
#    'data_year': 1994},
#   {'unknown': 70,
#    'range_0_9': 62,
#    'range_10_19': 523,
#    'range_20_29': 296,
#    'range_30_39': 304,
#    'range_40_49': 112,
#    'range_50_59': 72,
#    'range_60_69': 20,
#    'range_70_79': 7,
#    'range_80_89': 0,
#    'range_90_99': 3,
#    'data_year': 1996},
#   {'unknown': 98,
#    'range_0_9': 0,
#    'range_10_19': 208,
#    'range_20_29': 307,
#    'range_30_39': 167,
#    'range_40_49': 73,
#    'range_50_59': 24,
#    'range_60_69': 17,
#    'range_70_79': 3,
#    'range_80_89': 2,
#    'range_90_99': 0,
#    'data_year': 1993},
#   {'unknown': 452,
#    'range_0_9': 210,
#    'range_10_19': 2134,
#    'range_20_29': 1227,
#    'range_30_39': 856,
#    'range_40_49': 686,
#    'range_50_59': 297,
#    'range_60_69': 116,
#    'range_70_79': 37,
#    'range_80_89': 5,
#    'range_90_99': 3,
#    'data_year': 2007},
#   {'unknown': 274,
#    'range_0_9': 163,
#    'range_10_19': 1469,
#    'range_20_29': 686,
#    'range_30_39': 612,
#    'range_40_49': 359,
#    'range_50_59': 138,
#    'range_60_69': 57,
#    'range_70_79': 14,
#    'range_80_89': 4,
#    'range_90_99': 12,
#    'data_year': 2000},
#   {'unknown': 210,
#    'range_0_9': 68,
#    'range_10_19': 659,
#    'range_20_29': 482,
#    'range_30_39': 420,
#    'range_40_49': 312,
#    'range_50_59': 132,
#    'range_60_69': 49,
#    'range_70_79': 15,
#    'range_80_89': 7,
#    'range_90_99': 1,
#    'data_year': 2003}],
#  'pagination': {'count': 162, 'page': 0, 'pages': 1, 'per_page': 0}}

# %%
#Age data looks pretty straightforward - count of victims by age, by year 

age_data = pd.DataFrame(age_response['results'])
age_data = age_data.sort_values(by='data_year', ascending=False)

age_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9777362e832c> in <module>
#       1 #Age data looks pretty straightforward - count of victims by age, by year
#       2
# ----> 3 age_data = pd.DataFrame(age_response['results'])
#       4 age_data = age_data.sort_values(by='data_year', ascending=False)
#       5
#
# NameError: name 'pd' is not defined

# %%
test_query = "https://api.usa.gov/crime/fbi/sapi/api/summarized/state/LA/homicide/2010/2017?api_key=" + ld_dg_key

test_response = requests.get(test_query).json()
test_response
# Out:
# {'results': [{'ori': 'LA0010000',
#    'data_year': 2010,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010000',
#    'data_year': 2011,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010000',
#    'data_year': 2012,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010000',
#    'data_year': 2013,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 1,
#    'actual': 2},
#   {'ori': 'LA0010000',
#    'data_year': 2014,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010000',
#    'data_year': 2015,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 1},
#   {'ori': 'LA0010000',
#    'data_year': 2016,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 4,
#    'actual': 7},
#   {'ori': 'LA0010000',
#    'data_year': 2017,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010100',
#    'data_year': 2010,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 1},
#   {'ori': 'LA0010100',
#    'data_year': 2011,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 2,
#    'actual': 3},
#   {'ori': 'LA0010100',
#    'data_year': 2012,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 1,
#    'actual': 4},
#   {'ori': 'LA0010100',
#    'data_year': 2013,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010100',
#    'data_year': 2014,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 8,
#    'actual': 15},
#   {'ori': 'LA0010100',
#    'data_year': 2015,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 2,
#    'actual': 5},
#   {'ori': 'LA0010100',
#    'data_year': 2016,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 1,
#    'actual': 3},
#   {'ori': 'LA0010100',
#    'data_year': 2017,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 1,
#    'actual': 3},
#   {'ori': 'LA0010200',
#    'data_year': 2010,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010200',
#    'data_year': 2011,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010200',
#    'data_year': 2012,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 0},
#   {'ori': 'LA0010200',
#    'data_year': 2013,
#    'offense': 'homicide',
#    'state_abbr': 'LA',
#    'cleared': 0,
#    'actual': 1}],
#  'pagination': {'count': 1767, 'page': 0, 'pages': 89, 'per_page': 20}}

# %%
#API Call to National-level offender-data-controller for homicide only 
# 
#FORMAT:  https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/offender/national/{variable}?api_key=

age_query_url = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/offender/national/age?api_key=" + dg_key
count_query_url = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/offender/national/count?api_key=" + dg_key
ethnicity_query_url = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/offender/national/ethnicity?api_key=" + dg_key
sex_query_url = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/offender/national/sex?api_key=" + dg_key
race_query_url = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/homicide/offender/national/race?api_key=" + dg_key


OFF_age_response = requests.get(age_query_url).json()
OFF_count_response = requests.get(count_query_url).json()  
OFF_ethnicity_response = requests.get(ethnicity_query_url).json()
OFF_sex_response = requests.get(sex_query_url).json()
OFF_race_response = requests.get(race_query_url).json()

# %%
pprint(relationship_response)

# %%
#Age data looks pretty straightforward - count of victims by age, by year 

age_data = pd.DataFrame(age_response['results'])
age_data = age_data.sort_values(by='data_year', ascending=False)

age_data
